# %%
# %cd ..
# Out:
# /Users/maimai/Desktop/project/May

# %%
import builtins
builtins.uclresearch_topic = 'GIVENCHY'
# builtins.uclresearch_topic = 'HAWKING'
# builtins.uclresearch_topic = 'NYC'
# builtins.uclresearch_topic = 'FLORIDA'
from configuration import config
from configuration import dzcnapy_plotlib as dzcnapy


from tqdm import tqdm
import os
import pickle
import math
import numpy as np
import networkx as nx
import pandas as pd
from collections import Counter
import operator

# Plotting
import matplotlib
# # matplotlib.use('Agg')
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns

# Networkx
from networkx.drawing.nx_agraph import graphviz_layout
# Out:
# ('Reading config file from location: '
#  '/Users/maimai/Desktop/project/May/configuration/env.properties')
# {'calculate': {'analysis': True,
#                'network': True,
#                'uniquetweets': True,
#                'uniqueusers': True},
#  'data': {'dates': ['2018-03-11', '2018-03-12', '2018-03-13'],
#           'eventname': "Givenchy's Death",
#           'phrases': ['givenchy%20death', 'givenchy%20passed%20away'],
#           'starttime': 'Mar 12 08:20:00 -0500 2018'},
#  'path': {'crawl': {'followers': '/Users/maimai/Desktop/project/May/followers',
#                     'friends': '/Users/maimai/Desktop/project/May/friends'},
#           'cwd': '/Users/maimai/Desktop/project/May/data/givenchy',
#           'ml': '/Users/maimai/Desktop/project/May/data/givenchy/pickle',
#           'networkx': {'all': '/Users/maimai/Desktop/project/May/data/givenchy/pickle/networkx_all.dat',
#                        'friends': '/Users/maimai/Desktop/project/May/data/givenchy/pickle/networkx_friends.dat',
#                        'potential': '/Users/maimai/Desktop/project/May/data/givenchy/pickle/networkx_potential.dat'},
#           'pickle': {'exposed_user_ids_selected': '/Users/maimai/Desktop/project/May/data/givenchy/pickle/exposed_user_ids_selected.dat',
#                      'followers': '/Users/maimai/Desktop/project/May/data/givenchy/pickle/followers.dat',
#                      'followersneedcrawl': '/Users/maimai/Desktop/project/May/data/givenchy/pickle/followersneedcrawl.dat',
#                      'friends': '/Users/maimai/Desktop/project/May/data/givenchy/pickle/friends.dat',
#                      'infected_user_ids': '/Users/maimai/Desktop/project/May/data/givenchy/pickle/infected_user_ids.dat',
#                      'needcrawl': '/Users/maimai/Desktop/project/May/data/givenchy/pickle/needcrawl.dat',
#                      'network': '/Users/maimai/Desktop/project/May/data/givenchy/pickle/network.dat',
#                      'tweets': '/Users/maimai/Desktop/project/May/data/givenchy/pickle/tweets.dat',
#                      'users': '/Users/maimai/Desktop/project/May/data/givenchy/pickle/users.dat'},
#           'result': '/Users/maimai/Desktop/project/May/data/givenchy/result',
#           'twitter': '/Users/maimai/Desktop/project/May/data/givenchy/twitter'},
#  'save_to_file': 'False',
#  'timeframe': '1440'}
# /Users/maimai/Desktop/project/May/data/givenchy/pickle

# %%
n_bytes = 2**31
max_bytes = 2**31 - 1

path = "/Users/maimai/Desktop/project/May/data/givenchy/pickle"  

def write_to_pickle(file_path, data):

    bytes_out = pickle.dumps(data)
    with open(file_path, 'wb') as f_out:
        for idx in range(0, n_bytes, max_bytes):
            f_out.write(bytes_out[idx:idx+max_bytes])

def load_pickle(file_path):
    bytes_in = bytearray(0)
    input_size = os.path.getsize(file_path)
    with open(file_path, 'rb') as f_in:
        for _ in range(0, input_size, max_bytes):
            bytes_in += f_in.read(max_bytes)
    return pickle.loads(bytes_in)

# %%
project_name = config.settings['data']['eventname']
timeframe = config.settings['timeframe']
save_to_file = config.settings['save_to_file'] == 'True'
window = 30
# unique_users = config.load_users_dataframe()
# users = load_pickle(path+'/users.dat')
# network_friends = config.load_networkx_friends()
# network_potential = config.load_networkx_potential()
users = load_pickle(path+'/users.dat')

# %%
unique_users = load_pickle(path+'/Stanford_network_simulation_0.6_b_new.pkl')
# users

# %%
unique_users['user']=users['screen_name']
unique_users['source_index'] = None

for i in range(len(unique_users)):
    source_id = unique_users.loc[i,'source_id']
 
    source_index = unique_users[unique_users.user_id.isin([source_id])].index.values
#     print(source_index)
    if len(source_index) != False:
        unique_users.loc[i,'source_index']=int(source_index)
        unique_users.loc[i,'time_since_seed']=unique_users.loc[i,'time_lapsed']-unique_users.loc[int(source_index),'time_lapsed']
#         print(i)
unique_users
# Out:
#       t_current    user_id                                  source_candidates  \
# 0           120  214328887  [105, 62, 147, 148, 42, 124, 32, 10, 96, 18, 1...
# 1            30   34428380  [0, 12, 11, 110, 33, 118, 167, 78, 18, 74, 90,...
# 2            30   17116707  [18, 56, 52, 111, 153, 97, 38, 35, 31, 169, 20...
# 3            30   28465635  [2, 111, 36, 158, 83, 118, 179, 148, 65, 130, ...
# 4            30  380580781  [18, 96, 35, 0, 66, 32, 156, 75, 55, 54, 25, 4...
# 5            30   18996905  [4, 64, 42, 173, 66, 155, 153, 112, 43, 156, 2...
# 6            30  221036078  [148, 8, 83, 68, 46, 0, 124, 113, 116, 33, 31,...
# 7            30  153460275  [6, 115, 31, 23, 82, 62, 44, 18, 20, 173, 14, ...
# 8            30  107830991  [10, 61, 35, 28, 41, 56, 52, 3, 49, 113, 69, 9...
# 9            30   17868918  [8, 87, 123, 20, 37, 16, 66, 95, 80, 111, 69, ...
# 10           30  151338729  [28, 50, 54, 112, 36, 20, 73, 71, 173, 69, 18,...
# 11           30  222261763  [10, 84, 75, 23, 31, 137, 2, 74, 20, 105, 88, ...
# 12           30   19705747  [159, 62, 3, 61, 82, 87, 193, 146, 33, 165, 80...
# 13           30   88323281  [11, 24, 32, 154, 20, 135, 174, 97, 73, 108, 3...
# 14           30   19933035  [61, 36, 137, 31, 20, 52, 95, 18495, 18444, 17...
# 15           30  149538028  [14, 86, 49, 112, 61, 47, 41, 102, 70, 123, 0,...
# 16           30  158419434  [83, 107, 0, 146, 42, 15, 37, 41, 62, 25, 10, ...
# 17           30   17434613  [16, 78, 131, 42, 109, 133, 110, 147, 45, 30, ...
# 18           30  153226312  [15, 19, 60, 117, 74, 47, 53, 43, 135, 49, 8, ...
# 19           30  364971269  [42, 109, 110, 158, 95, 4149, 18907, 4133, 184...
# 20           30  100581193  [31, 70, 41, 36, 8, 33, 87, 140, 147, 100, 18,...
# 21           30   69592091  [61, 28, 79, 41, 105, 56, 127, 15, 27, 155, 20...
# 22           30  187773078  [10, 18, 20, 78, 49, 41, 96, 61, 25, 23, 4, 70...
# 23           30  406628822  [135, 21, 10, 18, 20, 37, 87, 137, 54, 68, 0, ...
# 24           30  460282402  [138, 16, 108, 31, 42, 19, 85, 4133, 34128, 18...
# 25           30  280935165  [20, 96, 18, 58, 111, 156, 69, 90, 59, 38, 76,...
# 26           30  437804658  [25, 68, 124, 88, 76, 77, 18, 41, 100, 165, 32...
# 27           30   27633075  [11, 88, 136, 96, 53, 42, 154, 130, 10, 23, 33...
# 28           30  285312927  [23, 41, 135, 165, 68, 123, 105, 111, 147, 14,...
# 29           30  131613362  [49, 88, 66, 54, 114, 173, 20, 58, 84, 28, 55,...
# ...         ...        ...                                                ...
# 69983       NaN  165153568                                            [35068]
# 69984       NaN   59953940                                                 []
# 69985       NaN   56222976                                                 []
# 69986       NaN  162157731                                            [70004]
# 69987       NaN  152011250                                     [69986, 70004]
# 69988       NaN  134894667                                            [69987]
# 69989       NaN   28016093                                                 []
# 69990       NaN  137772184                                                 []
# 69991       NaN  336218834                                            [69983]
# 69992       NaN  146229554                                                 []
# 69993       NaN  240895600                                                 []
# 69994       NaN   49037471                                                 []
# 69995       NaN  179167773                [69994, 16989, 69985, 69989, 69984]
# 69996       NaN  250733287                                                 []
# 69997       NaN  281765007                [69996, 69993, 70009, 70003, 69992]
# 69998       NaN  150319193                                     [69985, 69982]
# 69999       NaN  218640513                                     [69982, 70004]
# 70000       NaN   61497784                                                 []
# 70001       NaN   63135128                [69981, 69993, 48381, 70002, 69997]
# 70002       NaN  206918348                                                 []
# 70003       NaN   93641182                                            [35068]
# 70004       NaN   53811382                                                 []
# 70005       NaN   48108211                                            [70000]
# 70006       NaN  362077620                              [69986, 69999, 70004]
# 70007       NaN  165498547                                                 []
# 70008       NaN  253509115                                     [70003, 57826]
# 70009       NaN   63784655                                            [69992]
# 70010       NaN   63503127                                                 []
# 70011       NaN   75829996                                            [69991]
# 70012       NaN  148563360                                            [70004]
#
#                                         infec_candidates  followers_count  \
# 0      [1, 83, 70, 16, 40, 4, 76, 113, 156, 75, 39, 6...             2090
# 1      [51, 34, 93, 9, 58, 72, 135, 149, 1801, 2947, ...           305257
# 2      [3, 82, 125, 113, 39, 62, 116, 70, 124, 58, 14...            11756
# 3      [161, 38, 86, 76, 12, 84, 72, 141, 100, 8, 53,...            57992
# 4      [5, 87, 51, 140, 33, 22, 72, 58, 47, 10, 83, 6...            15033
# 5      [63, 129, 9, 1, 72, 4170, 14875, 18521, 14885,...           284075
# 6      [7, 72, 52, 81, 118, 114, 56, 86, 37, 53, 41, ...             2121
# 7      [84, 75, 72, 1, 10, 125, 9, 5, 18471, 18503, 1...             4710
# 8      [9, 58, 20, 77, 54, 6, 31, 43, 165, 21, 153, 3...            11627
# 9      [51, 39, 81, 93, 58, 122, 72, 144, 4159, 4170,...            16996
# 10     [11, 22, 63, 8, 35, 94, 33, 58, 83, 149, 23, 2...            41712
# 11     [13, 27, 51, 42, 118, 1, 58, 127, 59, 129, 147...             5399
# 12     [1, 51, 84, 58, 72, 4112, 16960, 4219, 22771, ...           669869
# 13     [130, 139, 62, 1, 44, 57, 138, 86, 131, 120, 1...            20883
# 14     [15, 125, 81, 37, 33, 13, 3, 39, 9, 84, 115, 2...              652
# 15     [18, 21, 56, 62, 94, 16, 42, 58, 43, 96, 35, 5...            17797
# 16     [17, 30, 70, 125, 9, 24, 73, 122, 59, 58, 180,...            14488
# 17     [72, 132, 58, 92, 51, 74, 1, 84, 9806, 17025, ...            57400
# 18     [22, 2, 4, 59, 34, 25, 118, 79, 123, 146, 112,...            13085
# 19     [18, 49, 130, 108, 1, 75, 24, 84, 31, 146, 72,...              537
# 20     [62, 25, 22, 38, 69, 10, 75, 111, 9, 13, 21, 1...             3444
# 21     [88, 76, 165, 96, 73, 51, 23, 32, 86, 66, 125,...            40064
# 22     [122, 44, 47, 58, 51, 42, 37, 127, 33, 94, 27,...            10803
# 23     [84, 53, 122, 83, 11, 58, 49, 28, 22, 94, 7, 2...             3616
# 24     [13, 73, 72, 100, 58, 84, 3, 5, 27, 135, 170, ...              237
# 25     [26, 42, 44, 122, 165, 72, 32, 70, 94, 22, 13,...            32706
# 26     [51, 1, 105, 62, 39, 97, 96, 94, 49, 20, 58, 2...             1627
# 27     [21, 39, 125, 94, 149, 5, 51, 84, 1, 58, 9, 93...            29557
# 28     [10, 21, 8, 39, 88, 51, 5, 69, 94, 29, 81, 62,...             3700
# 29     [68, 122, 32, 51, 77, 140, 56, 53, 75, 81, 148...            11273
# ...                                                  ...              ...
# 69983                      [18900, 58, 69991, 1, 84, 72]              281
# 69984               [18900, 58, 16960, 84, 69995, 16951]              445
# 69985  [16951, 16960, 69995, 69982, 30281, 35068, 116...              163
# 69986                              [69982, 70006, 69987]              355
# 69987         [69988, 11609, 18900, 41049, 69982, 30281]              193
# 69988                                                 []              121
# 69989       [338, 16960, 69995, 58, 16985, 18900, 16951]              997
# 69990  [30281, 338, 58, 1, 96, 4159, 84, 72, 11609, 8...             1353
# 69991  [1, 84, 81, 69982, 35068, 18900, 4112, 58, 415...              202
# 69992                              [17309, 70009, 69997]             1709
# 69993                       [70001, 69997, 37887, 17309]              527
# 69994                       [69995, 16989, 16960, 16951]              175
# 69995                              [16960, 16951, 16985]              713
# 69996                              [69997, 18900, 67288]              184
# 69997                                     [17309, 70001]            18654
# 69998                       [30281, 35068, 11609, 18900]             2447
# 69999                              [17309, 70006, 16960]              734
# 70000  [84, 58, 70005, 72, 30281, 69981, 18900, 67288...              845
# 70001                                            [67288]           320353
# 70002                            [338, 72, 70001, 69981]              103
# 70003         [16989, 18900, 37887, 17309, 70008, 69997]              359
# 70004  [69986, 69982, 70006, 69987, 41049, 69999, 70012]              454
# 70005                                                 []           319075
# 70006  [67288, 69982, 4112, 16960, 84, 58, 1, 72, 17309]              453
# 70007                                     [16960, 35068]              346
# 70008                                            [18900]             1028
# 70009                              [17309, 69997, 18900]              427
# 70010                             [72, 18900, 1, 84, 58]              432
# 70011                                 [84, 69982, 18900]              448
# 70012                                                 []              161
#
#        friends_count  source_id seed_user_id  SIR generations time_lapsed  \
# 0                 46  214328887    214328887    1           0           3
# 1                181  214328887    214328887    1           1           5
# 2                498   43003845     76576753    1           3           5
# 3               1482  214328887    214328887    1           1           5
# 4                219   43003845     76576753    1           3           5
# 5                 68   40981798    214328887    1           2           5
# 6                206  214328887    214328887    1           1           6
# 7                 35  214328887    214328887    1           1           6
# 8                934  214328887    214328887    1           1           6
# 9                552  214328887    214328887    1           1           6
# 10               198    6581292    214328887    1           2           5
# 11               512  214328887    214328887    1           1           6
# 12               600  274153775     83250127    1           2           5
# 13               834  274153775     83250127    1           2           5
# 14               120  100581193     83250127    1           3           6
# 15               255  280935165    214328887    1           3           6
# 16              3531    8163442     83250127    1           2           5
# 17               212   54228724     83250127    1           2           5
# 18                28   43003845     76576753    1           3           5
# 19               252  307458983     76576753    1           4           6
# 20                11  274153775     83250127    1           2           5
# 21               967   43003845     76576753    1           3           5
# 22               182   43003845     76576753    1           3           5
# 23               268  274153775     83250127    1           2           5
# 24                68  226629405     83250127    1           2           5
# 25               124   40981798    214328887    1           2           5
# 26               328  153226312     76576753    1           4           6
# 27               233  226629405     83250127    1           2           5
# 28                59        NaN          NaN  NaN         NaN         NaN
# 29               134   40981798    214328887    1           2           5
# ...              ...        ...          ...  ...         ...         ...
# 69983            719        NaN          NaN  NaN         NaN         NaN
# 69984            273        NaN          NaN  NaN         NaN         NaN
# 69985            280        NaN          NaN  NaN         NaN         NaN
# 69986            172        NaN          NaN  NaN         NaN         NaN
# 69987              7        NaN          NaN  NaN         NaN         NaN
# 69988            220        NaN          NaN  NaN         NaN         NaN
# 69989            288        NaN          NaN  NaN         NaN         NaN
# 69990            178        NaN          NaN  NaN         NaN         NaN
# 69991            199        NaN          NaN  NaN         NaN         NaN
# 69992            234        NaN          NaN  NaN         NaN         NaN
# 69993            194        NaN          NaN  NaN         NaN         NaN
# 69994             94        NaN          NaN  NaN         NaN         NaN
# 69995            543        NaN          NaN  NaN         NaN         NaN
# 69996            271        NaN          NaN  NaN         NaN         NaN
# 69997            152        NaN          NaN  NaN         NaN         NaN
# 69998            378        NaN          NaN  NaN         NaN         NaN
# 69999            384        NaN          NaN  NaN         NaN         NaN
# 70000           1011        NaN          NaN  NaN         NaN         NaN
# 70001           1444        NaN          NaN  NaN         NaN         NaN
# 70002            191        NaN          NaN  NaN         NaN         NaN
# 70003            680        NaN          NaN  NaN         NaN         NaN
# 70004            361        NaN          NaN  NaN         NaN         NaN
# 70005            308        NaN          NaN  NaN         NaN         NaN
# 70006            104        NaN          NaN  NaN         NaN         NaN
# 70007             50        NaN          NaN  NaN         NaN         NaN
# 70008            571        NaN          NaN  NaN         NaN         NaN
# 70009            336        NaN          NaN  NaN         NaN         NaN
# 70010            106        NaN          NaN  NaN         NaN         NaN
# 70011            479        NaN          NaN  NaN         NaN         NaN
# 70012             59        NaN          NaN  NaN         NaN         NaN
#
#       time_since_seed             user source_index
# 0                   0     xsolnechnaya            0
# 1                   2   schzimmydeanie            0
# 2                   1    paramorespain           84
# 3                   2   paramorebrasil            0
# 4                   1      SWEparamore           84
# 5                   1    FueledByRamen           58
# 6                   3   paramoreDomRep            0
# 7                   3   Paramorefansde            0
# 8                   3       paramoreCL            0
# 9                   3     adamsamiljan            0
# 10                  1       USParamore           50
# 11                  3    TaylorYorkArg            0
# 12                  1  KerrangMagazine           54
# 13                  1  PARAMOREandMore           54
# 14                  1       paramorePT           20
# 15                  1     ParamoreINTL           25
# 16                  1   itsdouglasyall          131
# 17                  1   ElektraOficial           45
# 18                  1    MutilatedFace           84
# 19                  1         veroalvs           42
# 20                  1   13ReasonsWhyCl           54
# 21                  1        Jamballam           84
# 22                  1     HayleyBrasil           84
# 23                  1       ParamoreBE           54
# 24                  1    JeremyDBrasil          108
# 25                  1     hayleys_hair           58
# 26                  1     ParaFamilyGB           18
# 27                  1   kittykatcamsey          108
# 28                NaN  ParamoreBritain         None
# 29                  1   ParamoreCanada           58
# ...               ...              ...          ...
# 69983             NaN        pedr0agst         None
# 69984             NaN    cherrrybomb__         None
# 69985             NaN        SAMARATCC         None
# 69986             NaN        anthony2_         None
# 69987             NaN     luanaingridy         None
# 69988             NaN       _saahsilva         None
# 69989             NaN     MarinaGuirro         None
# 69990             NaN       diablosita         None
# 69991             NaN        WeirdYeah         None
# 69992             NaN      Josholatras         None
# 69993             NaN           th3stw         None
# 69994             NaN   priscilascheer         None
# 69995             NaN           etpams         None
# 69996             NaN      luizagisely         None
# 69997             NaN          distr13         None
# 69998             NaN  Todoposerdespn_         None
# 69999             NaN       herestobia         None
# 70000             NaN         ldmlcstr         None
# 70001             NaN      ParisFilmes         None
# 70002             NaN         pollystw         None
# 70003             NaN        daenerysz         None
# 70004             NaN        narinhaol         None
# 70005             NaN    tati_bernardi         None
# 70006             NaN        ezraocean         None
# 70007             NaN       saraisfre_         None
# 70008             NaN     miojonuclear         None
# 70009             NaN     camillalima0         None
# 70010             NaN        masoqdigs         None
# 70011             NaN       leofromars         None
# 70012             NaN    Pequena_Jully         None
#
# [70013 rows x 14 columns]

# %%
write_to_pickle(path+'/Stanford_network_simulation_b_new_plot.pkl', unique_users)

# %%
# deleted_line = list(unique_users[unique_users.generations.isnull().values==True].index.values)
# all_line = list(unique_users.index.values)
# all_line.removeAll(deleted_line)
# all_line
a=[0,1,2,3,4,5]
unique_users=unique_users[unique_users.generations.isin(a)]
# unique_users.index[14]

# %%
network_all = nx.DiGraph()
for i in tqdm(range(len(unique_users))):
    index = unique_users.index[i]
    network_all.add_node(index,
                         user = unique_users.loc[index, 'user'],
                         user_id = unique_users.loc[index, 'user_id'],
                         time_lapsed = unique_users.loc[index, 'time_lapsed'],
                         followers_count = unique_users.loc[index, 'followers_count'],
                         friends_count = unique_users.loc[index, 'friends_count'],
                         generation = unique_users.loc[index, 'generations'],
                         time_since_seed = unique_users.loc[index, 'time_since_seed'],
                        )
    source_index = unique_users.loc[index, 'source_index']
#     if source_index is not None:
    network_all.add_edge(source_index, index)
network_all
# Out:
# 100%|██████████| 19493/19493 [00:02<00:00, 8228.92it/s]

# %%
def get_colors(depth):
    return sns.cubehelix_palette(depth, start=3, rot=1, reverse=True)
    sns.palplot(colors)
    
def plot_network(graph, title):
    plt.axis('off')
    pos = graphviz_layout(graph)
    nx.draw_networkx(graph, pos=pos, with_labels=False, **dzcnapy.small_attrs)
    depth = max(nx.get_node_attributes(graph,'generation').values()) + 1
    colors = get_colors(depth)
    color = [colors[graph.node[n]["generation"]] for n in graph]
    dzcnapy.small_attrs["node_color"] = color
    patchList = []
    for index in range(depth):
        data_key = mpatches.Patch(color=colors[index], label='Generation {}'.format(index))
        patchList.append(data_key)
    plt.legend(handles=patchList)
    dzcnapy.set_extent(pos, plt)
    dzcnapy.plot(title, [15, 12], save=True)

# %%
plot_network(network_all, "Sequential-seeding Strategy (b-new)")
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/pygraphviz/agraph.py:1341: RuntimeWarning: Warning: Could not load "/Applications/anaconda3/lib/graphviz/libgvplugin_pango.6.dylib" - file not found
#
#   warnings.warn(b"".join(errors).decode(self.encoding), RuntimeWarning)

# %%
# results_path = "/Users/maimai/Desktop/project/May/data/givenchy/pickle"
# title="Visualization of the entire network for event Givenchy's death"
# # plt.savefig(results_path+"/models.pdf")
# # plt.savefig("{}/{}.pdf".format(results_path, fname), dpi=600)
# dzcnapy.plot(network_all, [15, 12], save=)
